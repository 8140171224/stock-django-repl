# %%
# pandas, numpy, matplotlib, statsmodels 
import pandas as pd

# %%
fb = pd.read_csv('facebook.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-19-13507b81d2ba> in <module>
# ----> 1 fb = pd.read_csv('facebook.csv')
#
# /opt/virtualenvs/python3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
# !pip  install -r req.txt
# Out:
# ...
#      |████████████████████████████████| 9.2 MB 4.6 MB/s eta 0:00:01
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /opt/virtualenvs/python3/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-ph654njv/pandas_81376a7fb3924f92846d01f3f06cbee4/setup.py'"'"'; __file__='"'"'/tmp/pip-install-ph654njv/pandas_81376a7fb3924f92846d01f3f06cbee4/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-5k9fw193
#        cwd: /tmp/pip-install-ph654njv/pandas_81376a7fb3924f92846d01f3f06cbee4/
#   Complete output (1009 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.8
#   creating build/lib.linux-x86_64-3.8/pandas
#   copying pandas/__init__.py -> build/lib.linux-x86_64-3.8/pandas
# ...
